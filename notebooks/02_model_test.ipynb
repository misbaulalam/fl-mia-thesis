# %%
import sys
sys.path.append('../src')
from model import SimpleCNN
import torch

model = SimpleCNN(num_classes=10)

# create one fake batch: 4 images, 3 channels, 32x32 pixels
dummy_input = torch.randn(4, 3, 32, 32)
output = model(dummy_input)

print("Output shape:", output.shape)  # should be [4, 10]
print(output)
# Out:
# Output shape: torch.Size([4, 10])
# tensor([[ 0.1752, -0.0647,  0.0947,  0.1758, -0.0131, -0.0949, -0.1843, -0.1076,
#           0.1247, -0.0456],
#         [ 0.1476, -0.1066,  0.1481,  0.1424,  0.0547, -0.1481, -0.3106, -0.1161,
#           0.1402,  0.0607],
#         [ 0.0935, -0.1356,  0.1919,  0.1885,  0.0027, -0.1445, -0.2631,  0.0141,
#           0.0432, -0.1271],
#         [ 0.2589, -0.1709,  0.2944,  0.0701, -0.0089, -0.0424, -0.1642, -0.0745,
#           0.2050, -0.1081]], grad_fn=<AddmmBackward0>)
